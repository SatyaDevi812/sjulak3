# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn import preprocessing
import matplotlib.pyplot as plt 
plt.rc("font", size=14)
from sklearn.model_selection import train_test_split
from sklearn import metrics
import seaborn as sns
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)
from sklearn.metrics import classification_report
import statsmodels.api as sm

# %%
data = pd.read_excel('C:/Project Data/Emergency Dataset.xls')
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
data.cd_gender.replace(['M','F'],[1,0],inplace=True)

# %%
y = data['EM_MEMBER']

# %%
x = data.loc[:, ~data.columns.isin(['EM_MEMBER', 'member_id','birth_year'])]

# %%
x
# Out:
#        cd_gender  age  zip3  chr_count  chr_htn  chr_copd  chr_asthma  \
# 0              0   58   490          1        1         0           0
# 1              1   50   484          3        1         0           1
# 2              1   60   490          2        1         0           0
# 3              1   53   487          4        1         1           1
# 4              1   63   487          4        1         1           0
# 5              1   58   487          0        0         0           0
# 6              1   58   486          2        1         0           0
# 7              0   62   487          4        1         1           0
# 8              0   61   490          2        0         1           0
# 9              1   54   491          2        1         0           0
# 10             0   60   490          4        1         1           1
# 11             0   63   480          2        1         0           0
# ...

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=0)

# %% [markdown]
# # SVM

# %%
from sklearn import svm
clf = svm.SVC(gamma='scale')
clf.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
pred = clf.predict(X_test)
exp = y_test

# %%
print(metrics.classification_report(exp, pred))
print(metrics.confusion_matrix(exp, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.00      0.01      1481
#            1       0.70      1.00      0.83      3519
#
#     accuracy                           0.70      5000
#    macro avg       0.85      0.50      0.42      5000
# weighted avg       0.79      0.70      0.58      5000
#
# [[   5 1476]
#  [   0 3519]]

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5, metric='euclidean')
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
print(metrics.classification_report(y_test, y_pred))
print(metrics.confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.56      0.59      1481
#            1       0.82      0.87      0.84      3519
#
#     accuracy                           0.78      5000
#    macro avg       0.73      0.71      0.72      5000
# weighted avg       0.77      0.78      0.77      5000
#
# [[ 823  658]
#  [ 467 3052]]
